# %%
import pandas as pd

df = pd.read_excel("mode_dataset_ecommerce.xlsx")
print(df["Product_Category"].mode())
print(df["Product_Category"].value_counts())
# Out:
# 0    Shoes
# Name: Product_Category, dtype: str
# Product_Category
# Shoes      49
# Shirts     23
# Jeans      14
# Bags        7
# Watches     7
# Name: count, dtype: int64

# %%
df1 = pd.read_excel("fintech_dataset.xlsx")
print(df1["Monthly_Spend"].mean())
print(df1.sort_values(by="Monthly_Spend", ascending=False))
print(df1.drop([24, 39, 9, 35, 26, 38, 37], inplace=True))
print(df1["Monthly_Spend"].mean())
print(df1["Monthly_Spend"].median())
# Out:
# 2881.72
#    Customer_ID  Monthly_Spend
# 24         C25          15216
# 39         C40          12404
# 9          C10           9771
# 35         C36           3413
# 26         C27           3374
# 38         C39           3359
# 37         C38           3270
# 6           C7           3245
# 36         C37           3223
# 23         C24           3163
# 20         C21           3124
# 5           C6           3007
# 4           C5           2934
# 31         C32           2884
# 43         C44           2880
# 32         C33           2816
# 21         C22           2786
# 48         C49           2776
# 28         C29           2771
# 0           C1           2745
# 13         C14           2688
# 2           C3           2609
# 17         C18           2572
# 19         C20           2511
# 34         C35           2479
# 42         C43           2463
# 30         C31           2431
# 46         C47           2341
# 45         C46           2327
# ...

# %%
pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...
